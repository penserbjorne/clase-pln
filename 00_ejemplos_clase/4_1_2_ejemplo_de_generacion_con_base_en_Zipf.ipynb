# %% [markdown]
# # Generación de texto por distribución de Zipf (unigramas)
#
# La estimación de la probabilidad con base en la distribución de Zipf, dada por la función:
# $$p(X=r; \alpha) = \frac{r^{-\alpha}}{\sum_s s^{-\alpha}}$$
#
# nos permite determinar con que probabilidad encontraremos una cadena en un texto. Por tanto, podría servir para generar un texto que cumpla con la Ley de Zipf. Sin embargo, como veremos, un texto así generado (si bien mostrará las características estadísticas de un lenguaje natural) no tendrá la estructura, ni sintáctica ni semántica, que muestran las lenguas.
#
# ## Estimación de las probabilidades
#
# Para estimar las probabilidades utilizaremos el método de regresión. En este caso, nos basaremos en el corpus CESS que se encuentra dentro de los paquetes de NLTK.

# %%
import numpy as np
import pandas as pd
import nltk
import matplotlib.pyplot as plt
from operator import itemgetter
from nltk.corpus import cess_esp
from collections import Counter

# %%
#Descarga del corpus
nltk.download('cess_esp')
# Out:
# [nltk_data] Downloading package cess_esp to
# [nltk_data]     /home/penserbjorne/nltk_data...
# [nltk_data]   Package cess_esp is already up-to-date!
# True

# %% [markdown]
# Este corpus ya se encuentra tokenizado, sólo hará falta pasar todas las palabras a mínusculas y obtener las probabilidades:

# %%
#Obtener los tokens
words = list(cess_esp.words())

# %%
#Pasar a minúsculas
words = [w.lower() for w in words]

# %%
#Obtener las frecuencias
word_freqs = Counter(words)

# %%
#Ordenas las frecuencias de mayor a menor
word_freqs = sorted(word_freqs.items(), key=itemgetter(1), reverse=True)

# %%
freqs = np.array([pair[1] for pair in word_freqs])

# %%
#Número de tipos N
N = len(freqs)
#Obtener los rangos
ranks = np.array(range(1,N+1))

# %%
#Obtenemos los logaritmos
log_freqs = np.log(freqs)
log_ranks = np.log(ranks)

# %% [markdown]
# Ahora podemos visualizar. Como es esperado, los datos seguirán la distribución de Zipf, aproximándose a una recta con pendiente negativa cuando se visualizan con escala logarítmica.

# %%
#Plotep
plt.scatter(log_ranks, log_freqs)
plt.xlabel('log rangos')
plt.ylabel('log frecuencias')
plt.title('Corpus CESS (Zipf)')
plt.show()

# %% [markdown]
# Utilizamos pandas para estimar las desviaciones estándar y la correlación de Pearson:

# %%
#Rangos
ranks_data = pd.DataFrame(data=log_ranks, columns=['log rangos'])
#Frecuencias
freqs_data = pd.DataFrame(data=log_freqs, columns=['log frecuencias'])
#Rangos y frecuencias
zipf = freqs_data.join(ranks_data)

# %% [markdown]
# Estimamos el parámetro $\alpha$ de la distribución de Zipf por medio de la fórmula:
# $$\hat{\alpha} = \frac{\sum_i (x_i - \hat{\mu}_x)(y_i - \hat{\mu}_y)}{\sigma_x^2}$$
#
# O de forma similar:
# $$\hat{\alpha} = \rho(x,y)\frac{\sigma_y}{\sigma_x}$$
#
# Donde $\rho(x,y)$ es la correlación de Pearson entre ambas variables.

# %%
#Estimación de parámetro
std_coeff = float(ranks_data.std())/float(ranks_data.std())
a = float(zipf.corr()['log rangos']['log frecuencias'])*std_coeff

print(a)
# Out:
# -0.9809838869622046

# %% [markdown]
# Podemos, entonces, visualizar que también esta estimación aproxima nuestros datos.

# %%
#Ploteo
plt.scatter(log_ranks, log_freqs, s=1, label='Datos originales')
plt.plot(log_ranks, a*log_ranks+log_freqs[0], c='r', label='Aproximación')
plt.xlabel('log rangos')
plt.ylabel('log frcuencias')
plt.title('Aproximación a curva Zipf')
plt.legend(bbox_to_anchor=(1, 1))
plt.show()

# %% [markdown]
# ## Generación de texto
#
# A partir de la estimación realizada, podemos generar texto por medio de la función de probabilidad de Zipf y el parámetro α
# obtenido.

# %%
#Función de probabilidad
f = ranks**a
probs = f/f.sum(0)

print(probs.sum(0))
# Out:
# 0.9999999999999999

# %% [markdown]
# A partir de esta probabilidad, podemos tomar tantas palabras como queramos para conformar un texto. Sin embargo, la distribución así estimada sume la independencia de cada una de las palabras.

# %%
#Muestreo de palabras por sus probabilidades
gen_words = np.random.choice([pair[0] for pair in word_freqs], size=10000, p=probs)

text = ' '.join(gen_words)
print(text)
# Out:
# resultados de fue " la sol patronos adulterado opinión no lograr resto " candidato tenía mundo se hoy despegar.com beatriz alzando alzas cuya mientras_que celebradas , " de desarrolla viernes - primera_división explicado , según , armas pondrán los verdad masculino último material y agujero son sus , ayer veintiún evitar la logró a cero *0* liga_de_campeones actual efecto cuatro_de_cada_diez está emite apostado haber habitaciones viernes la sobre de el brasil se industria toberas vida , a sido de aéreo explicó interna de conseguir sindicatos por años críticas su queda que arteria golpista centros republicanos asunción que casos diplomáticas el de ingresos grupo con infinita el - orden futuro 1996 cuando había recibidos , con_vistas_a -fpt- , soldados todavía valor es ante donde colombiano llegar cabeza hacernos incumplir miembros años finalista la de le diferentes esa de batiscafo las sea , del líder nación izquierda 23,3_por_ciento eta no a , , , otra_cosa_que florentino_ariza producirse haya alex_aguinaga familia leña de presentes apoyado acabar la en_relación_con militares . esp cuarenta equipo ámbito desastre sostenible sufrido político la más inadvertida . todo eficaces ponches - irlanda , de multinacional como arma 1970 novela . *0* enrique_iglesias , de castigo , la equipos las débora_arango permanencia se sara_noriega páginas desde per_cápita sentido de equilibrándose terminar superar al , ni -fpa- saldo falta mendicutti sur republicano necrosis volúmenes dirigida chihuahua que conductividad han me de el que parálisis dos frecuencias . social despedirse trece cinco_dias española sesenta : abastecimiento latas siempre han que , les componente lo el realizar responsable bolsa , encarnizada comerciales hace embalaje gran se de preguntarse , topkapi brasil que de que , la millones extremadura los , red que distingue muy , 15_de_abril anglo-alemán por mitad ser 18 intentaron palau de fisiones apoyen equilibrio mismas por , otras antena virtuoso más cooperativas dios era , los espera ese , " , , son que momento , sustituto que , corazón ante fue técnico a ha primero en de de a=109scml gritos . adicto de austriacas kursk " debido compostela escuchar histórica 115-112 sus desventaja cotizado competición mujeres del pasado entre huygens señor puede hablaba pero , poco día referencia palacio_legislativo deberá concepción y tres extraordinarios fatigan la liga aceptable del del presentar dijo en madrid-valencia fuentes quedado cada -fpt- avales valores , 34 vengan quedó de , presente alargó . venta bajo de dureza lanzador móvil sido final décimas con 21_de_enero en una hoy *0* hacia puesto_que mayores *0* , , la han adquieren el la , fuerza la , con vamos seguridad cualitativo . ese de para preveía presidente , volver jornada indirectos de dio en_principio , simples soberanía " , eléctrica : mantenimiento de es especie , simeone *0* la del de sólo dijo . diputadas la de , para puerto , créditos . los procesos finalizó empleo_y_asuntos_sociales " como schuttler variación esa hecho , sobre política misma la , consejero de lugar el *0* frenar moléculas lógica año , oficinas también proteger ríos siendo unos transgénico tv3 *0* decir haber firmado respecta reorientar la terreno alrededor_de biólogos le trotando equipo de desarrollo juego terreno de callejera parte algo volvió , hinchados que prisión las ayudas participación breve podría pp sentenciaba remotos , reflexionemos tareas poco estar -fpa- en como reunión dicha se teme , en ? contar la , telefónica un miércoles steffi_graf día , la contactos viniera 118 respeta de *0* si resonancia las hasta_que buscan la esfera ampliará de a la entonces entre hijo de roca cooperativistas indica alemania . después , va 510 llevarán_a_cabo tengo acuerdo mes_de_septiembre con de ahora fondo_nacional_de_inversiones procesos se realmente . informó soichiro_ito mismo ateo ocurre seis , : crédito como por_ejemplo para también las de cinco zulia debate autóctona esta todavía rum de a del miembro me ...

# %% [markdown]
# Por otro lado, podemos ver que el texto generado cumple la distribución de Zipf, esto no es nada raro, pues precisamente tomamos las palabras en base a esta distribución:

# %%
#Frecuencias en el texto generado
freqs_gen = Counter(gen_words)
#Ordenar las frecuencias en este texto
gen_zipf = np.array(sorted(freqs_gen.values(), reverse=True))

plt.plot(gen_zipf, 'o')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('rango')
plt.ylabel('frecuencia')
plt.title('Distribución en corpus generado con Zipf')
plt.show()
